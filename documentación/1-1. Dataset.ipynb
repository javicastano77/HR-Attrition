# %% [markdown]
# # Original Dataset variables
#
#  - 1 - Age.
#  - 2 - Attrition: employee leaving the company (No, Yes).
#  - 3 - BusinessTravel: frecuency business travel (Tavel_Rarely , Travel_Frequently, Non_Travel).
#  - 4 - DailyRate: daily salary.
#  - 5 - Department: area where employee are based (Research & Development, Sales, Human Resources).
#  - 6 - DistanceFromHome: distance from work to home.
#  - 7 - Education: level of education.
#  - 8 - EducationField: area of employee studies(Life Sciences, Other, Medical, Marketing, Technical Degree, HR).
#  - 9 - EmployeeCount.
#  - 10 - EmployeeNumber: employee ID.
#  - 11 - EnvironmentSatisfaction: satistaction with the environment.
#  - 12 - Gender.
#  - 13 - HourlyRate: hourly salary.
#  - 14 - JobInvolvement: employee's involvement with the job.
#  - 15 - JobLevel: employee level.
#  - 16 - JobRole: employee role.
#  - 17 - JobSatisfaction: employee's satisfaction with the job.
#  - 18 - MaritalStatus: employee marital status (Single, Married, Divorced).
#  - 19 - MonthlyIncome: monthly salary.
#  - 20 - MonthlyRate.
#  - 21 - NumCompaniesWorked: number of companies in which employee has worked in.
#  - 22 - Over18: if employee is over 18 years old.
#  - 23 - OverTime: if employee works overtime (Yes, No).
#  - 24 - PercentSalaryHike: percentage of employee's salary hike.
#  - 25 - PerformanceRating: performance who has obtained employee.
#  - 26 - RelationshipSatisfaction: relationship staisfaction of employee.
#  - 27 - StandardHours: standard hours for a week workday of employee.
#  - 28 - StockOptionLevel: grade of posibility to get company stocks
#  - 29 - TotalWorkingYears: employee's laboral life.
#  - 30 - TrainingTimesLastYear: how many time employee enjoyed training in the last year.
#  - 31 - WorkLifeBalance: personal evaluation about employee's worklife.
#  - 32 - YearsAtCompany: total years of employee in the current company.
#  - 33 - YearsInCurrentRole: total years in current role.
#  - 34 - YearsSinceLastPromotion: years since the last promotion.
#  - 35 - YearsWithCurrManager: years with the current Manager.
#
#
# # Transformed Dataset variables
#
# Establish a new order by type of variable to use them for later ERD model
#
#
# #### Human variables:
#
# - 1 - employee_ID
# - 2 - age
# - 3 - gender
# - 4 - education
# - 5 - education_area
# - 6 - marital_status
#
# #### Employment variables:
#
# - 7 - department
# - 8 - job_level
# - 9 - job_role
# - 10 - business_travel
# - 11 - distance_home
# - 12 - overtime
# - 13 - standard_hours
#
# #### Salary variables:
#
# - 14 - daily_rate
# - 15 - hourly_rate
# - 16 - monthly_income
# - 17 - monthly_rate
#
# #### Employee career variables:
#
# - 18 - companies_worked
# - 19 - salary_hike_per
# - 20 - stockoptionlevel
# - 21 - working_years
# - 22 - training_lastyear
# - 23 - years_company
# - 24 - years_current_role
# - 25 - years_last_promotion
# - 26 - years_current_manager
#
# #### Employee performance variables:
#
# - 27 - environment_satisfaction
# - 28 - worklife_balance
# - 29 - job_involvement
# - 30 - job_satisfaction
# - 31 - performance_rating
# - 32 - relationship_satisfaction
#
# #### New variables creation:
#
# - 33 - age_interval
# - 34 - education_cat: establish ordinal categories(1=Below College, 2=College, 3=Bachelor, 4=Master, 5=Doctor).
# - 35 - environment_satisf_cat: establish ordinal categories (1=Low, 2=Medium, 3=High, 4=Very High).
# - 36 - job_involvement_cat: establish ordinal categories (1=Low, 2=Medium, 3=High, 4=Very High).
# - 37 - job_level: establish ordinal categories (1=associate, 2=analyst, 3=specialist, 4=manager,5=director).
# - 38 - job_satisf_cat:establish ordinal categories (1=Low, 2=Medium, 3=High, 4=Very High).
# - 39 - worklife_balance_cat: establish ordinal categories (1=Bad, 2=Good, 3=Better, 4=Best)
#
# #### Delete variables:
#
# - Over18: not relevant for analysis (same values for all rows).
# - EmployeeCount: not relevant for analysis (same values for all rows).
