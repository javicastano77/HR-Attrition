# %%
# Paso 0: Importar libreria Pandas para trabajar con DFs

import pandas as pd

# %%
# Paso 0: Chequear ubicación de la folder correcta

# %ls
# Out:
#  El volumen de la unidad C es Windows
#  El número de serie del volumen es: 788B-24D1
#
#  Directorio de C:\Users\javie\OneDrive\Escritorio\Ironhack\Final Project\HR-Leave\ERD Model
#
# 19/02/2024  14:03    <DIR>          .
# 18/02/2024  21:08    <DIR>          ..
# 19/02/2024  13:06    <DIR>          .ipynb_checkpoints
# 19/02/2024  13:55            52.151 1 - Employee.ipynb
# 19/02/2024  14:01            50.709 2 - Job.ipynb
# 19/02/2024  14:03            43.907 3 - Salary.ipynb
# 19/02/2024  13:05            42.500 4 - Career.ipynb
# 19/02/2024  13:06            45.603 5 - Performance.ipynb
# 19/02/2024  13:53           100.332 employee.csv
# 18/02/2024  18:55           332.178 hr_df.csv
# 19/02/2024  14:00           102.859 job.csv
# 19/02/2024  14:03            35.487 salary.csv
#                9 archivos        805.726 bytes
#                3 dirs  361.768.587.264 bytes libres

# %%
# Paso 0: Eliminar restricciones de display para poder ver todas las columnas


pd.options.display.max_columns=None

# %%
# Paso 1: Cargar DF limpio sobre el que trabajar

df = pd.read_csv('hr_df.csv')

df
# Out:
#      employee_id attrition  age age_interval  gender  education  \
# 0        RDO0001       Yes   41        40-49  Female          2
# 1        RDO0002        No   49        40-49    Male          1
# 2        RDO0003       Yes   37        30-39    Male          2
# 3        RDO0004        No   33        30-39  Female          4
# 4        RDO0005        No   27        18-29    Male          1
# ...          ...       ...  ...          ...     ...        ...
# 1465     RDO1466        No   36        30-39    Male          2
# 1466     RDO1467        No   39        30-39    Male          1
# 1467     RDO1468        No   27        18-29    Male          3
# 1468     RDO1469        No   49        40-49    Male          3
# 1469     RDO1470        No   34        30-39    Male          3
#
#       education_cat education_area marital_status              department  \
# 0           College  Life Sciences         Single                   Sales
# ...

# %%
# Paso 2: Generar nuevo DF para ERD basado en dimensión Career

career = df[['companies_worked','salary_hike_per','stock_option','working_years','training_lastyear','years_company','years_curr_role','years_last_promotion','years_curr_manager']]

career
# Out:
#       companies_worked  salary_hike_per  stock_option  working_years  \
# 0                    8               11             0              8
# 1                    1               23             1             10
# 2                    6               15             0              7
# 3                    1               11             0              8
# 4                    9               12             1              6
# ...                ...              ...           ...            ...
# 1465                 4               17             1             17
# 1466                 4               15             1              9
# 1467                 1               20             1              6
# 1468                 2               14             0             17
# 1469                 2               12             0              6
#
#       training_lastyear  years_company  years_curr_role  years_last_promotion  \
# ...

# %%
# Paso 3: Crear id para la Foreign Key en SQL

career['Career_id'] = career.index+1

career.insert(0, 'Career_id', career.pop('Career_id'))

career
# Out:
# C:\Users\javie\AppData\Local\Temp\ipykernel_5672\1577405210.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   career['Career_id'] = career.index+1
#       Career_id  companies_worked  salary_hike_per  stock_option  \
# 0             1                 8               11             0
# 1             2                 1               23             1
# 2             3                 6               15             0
# 3             4                 1               11             0
# 4             5                 9               12             1
# ...         ...               ...              ...           ...
# 1465       1466                 4               17             1
# ...

# %%
# Paso 4: Exportar el DF 'Career' para posterior uso en ERD

career.to_csv('career.csv',index=False)
