# %%
import pandas as pd

# %%
pd.options.display.max_columns=None

# %%
# %ls
# Out:
#  El volumen de la unidad C es Windows
#  El número de serie del volumen es: 788B-24D1
#
#  Directorio de C:\Users\javie\OneDrive\Escritorio\Ironhack\Final Project\HR-Attrition\First Approach
#
# 15/02/2024  23:28    <DIR>          .
# 15/02/2024  22:08    <DIR>          ..
# 15/02/2024  22:11    <DIR>          .ipynb_checkpoints
# 15/02/2024  23:28           298.520 Cleaning.ipynb
# 15/02/2024  13:43           227.977 WA_Fn-UseC_-HR-Employee-Attrition.csv
#                2 archivos        526.497 bytes
#                3 dirs  364.751.990.784 bytes libres

# %%
# Dataset upload

df = pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv')

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
# Lower to columns

df.columns = df.columns.str.lower()

df
# Out:
#       age attrition     businesstravel  dailyrate              department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       distancefromhome  education educationfield  employeecount  \
# ...

# %%
# Change columns name

df.rename(columns={'businesstravel': 'business_travel','dailyrate':'daily_rate','distancefromhome':'distance_home',
                   'educationfield':'education_area','employeenumber':'employee_id','environmentsatisfaction':'environment_satisf',
                   'hourlyrate':'hourly_rate','jobinvolvement':'job_involvement','joblevel':'job_level','jobrole':'job_role',
                   'jobsatisfaction':'job_satisfaction','maritalstatus':'marital_status','monthlyincome':'monthly_income',
                   'monthlyrate':'monthly_rate','numcompaniesworked':'companies_worked','percentsalaryhike':'salary_hike_per',
                   'performancerating':'performance_rating','relationshipsatisfaction':'relationship_satisf','standardhours':'standard_hours',
                   'stockoptionlevel':'stock_option','totalworkingyears':'working_years','trainingtimeslastyear':'training_lastyear',
                   'worklifebalance':'worklife_balance','yearsatcompany':'years_company','yearssincelastpromotion':'years_last_promotion',
                   'yearswithcurrmanager':'years_curr_manager','yearsincurrentrole':'years_curr_role',               
                  }, inplace=True)
df
# Out:
#       age attrition    business_travel  daily_rate              department  \
# 0      41       Yes      Travel_Rarely        1102                   Sales
# 1      49        No  Travel_Frequently         279  Research & Development
# 2      37       Yes      Travel_Rarely        1373  Research & Development
# 3      33        No  Travel_Frequently        1392  Research & Development
# 4      27        No      Travel_Rarely         591  Research & Development
# ...   ...       ...                ...         ...                     ...
# 1465   36        No  Travel_Frequently         884  Research & Development
# 1466   39        No      Travel_Rarely         613  Research & Development
# 1467   27        No      Travel_Rarely         155  Research & Development
# 1468   49        No  Travel_Frequently        1023                   Sales
# 1469   34        No      Travel_Rarely         628  Research & Development
#
# ...

# %%
# Delete irrelevant variables

df = df.drop(['over18','employeecount'],axis=1)

df
# Out:
#       age attrition    business_travel  daily_rate              department  \
# 0      41       Yes      Travel_Rarely        1102                   Sales
# 1      49        No  Travel_Frequently         279  Research & Development
# 2      37       Yes      Travel_Rarely        1373  Research & Development
# 3      33        No  Travel_Frequently        1392  Research & Development
# 4      27        No      Travel_Rarely         591  Research & Development
# ...   ...       ...                ...         ...                     ...
# 1465   36        No  Travel_Frequently         884  Research & Development
# 1466   39        No      Travel_Rarely         613  Research & Development
# 1467   27        No      Travel_Rarely         155  Research & Development
# 1468   49        No  Travel_Frequently        1023                   Sales
# 1469   34        No      Travel_Rarely         628  Research & Development
#
#       distance_home  education education_area  employee_id  \
# ...

# %%
print(df.age.min())
print(df.age.max())
# Out:
# 18
# 60

# %%
df.job_level.unique()
# Out:
# array([2, 1, 3, 4, 5], dtype=int64)

# %%
import pandas as pd

# Supongamos que ya tienes un DataFrame llamado 'df' con las columnas 'age', 'education', etc.

# Crear la variable de intervalos de edad
intervalos = [18, 30, 40, 50, 60, float('inf')]
etiquetas = ['18-29', '30-39', '40-49', '50-59', '60+']
df['age_interval'] = pd.cut(df['age'], bins=intervalos, labels=etiquetas, right=False)

# Mapear variables categóricas
mapp_2 = {1: 'Below College', 2: 'College', 3: 'Bachelor', 4: 'Master', 5: 'Doctor'}
df['education_cat'] = df['education'].map(mapp_2)

mapp_3 = {1: 'Low', 2: 'Medium', 3: 'High', 4: 'Very High'}
df['environment_satisf_cat'] = df['environment_satisf'].map(mapp_3)

mapp_4 = {1: 'Low', 2: 'Medium', 3: 'High', 4: 'Very High'}
df['job_involvement_cat'] = df['job_involvement'].map(mapp_4)

mapp_5 = {1: 'associate', 2: 'analyst', 3: 'specialist', 4: 'manager', 5: 'director'}
df['job_level'] = df['job_level'].map(mapp_5)

mapp_6 = {1: 'Low', 2: 'Medium', 3: 'High', 4: 'Very High'}
df['job_satisf_cat'] = df['job_satisfaction'].map(mapp_6)

mapp_7 = {1: 'Bad', 2: 'Good', 3: 'Better', 4: 'Best'}
df['worklife_balance_cat'] = df['worklife_balance'].map(mapp_7)

mapp_8 = {1: 'Low', 2: 'Good', 3: 'Excellent', 4: 'Outstanding'}
df['performance_rating_cat'] = df['performance_rating'].map(mapp_8)

mapp_9 = {1: 'Low', 2: 'Medium', 3: 'High', 4: 'Very High'}
df['relationship_satisf_cat'] = df['relationship_satisf'].map(mapp_9)

df
# Out:
#       age attrition    business_travel  daily_rate              department  \
# 0      41       Yes      Travel_Rarely        1102                   Sales
# 1      49        No  Travel_Frequently         279  Research & Development
# 2      37       Yes      Travel_Rarely        1373  Research & Development
# 3      33        No  Travel_Frequently        1392  Research & Development
# 4      27        No      Travel_Rarely         591  Research & Development
# ...   ...       ...                ...         ...                     ...
# 1465   36        No  Travel_Frequently         884  Research & Development
# 1466   39        No      Travel_Rarely         613  Research & Development
# 1467   27        No      Travel_Rarely         155  Research & Development
# 1468   49        No  Travel_Frequently        1023                   Sales
# 1469   34        No      Travel_Rarely         628  Research & Development
#
#       distance_home  education education_area  employee_id  \
# ...

# %%
# Order sociodemographic variables:

df.insert(0, 'attrition', df.pop('attrition'))
df.insert(1, 'employee_id', df.pop('employee_id'))
df.insert(2, 'age', df.pop('age'))
df.insert(3, 'age_interval', df.pop('age_interval'))
df.insert(4, 'gender', df.pop('gender'))
df.insert(5, 'education', df.pop('education'))
df.insert(6, 'education_area', df.pop('education_area'))
df.insert(7, 'marital_status', df.pop('marital_status'))

df
# Out:
#      attrition  employee_id  age age_interval  gender  education  \
# 0          Yes            1   41        40-49  Female          2
# 1           No            2   49        40-49    Male          1
# 2          Yes            4   37        30-39    Male          2
# 3           No            5   33        30-39  Female          4
# 4           No            7   27        18-29    Male          1
# ...        ...          ...  ...          ...     ...        ...
# 1465        No         2061   36        30-39    Male          2
# 1466        No         2062   39        30-39    Male          1
# 1467        No         2064   27        18-29    Male          3
# 1468        No         2065   49        40-49    Male          3
# 1469        No         2068   34        30-39    Male          3
#
#      education_area marital_status    business_travel  daily_rate  \
# 0     Life Sciences         Single      Travel_Rarely        1102
# ...

# %%
# Order employment variables:

df.insert(8, 'department', df.pop('department'))
df.insert(9, 'job_level', df.pop('job_level'))
df.insert(10, 'job_role', df.pop('job_role'))
df.insert(11, 'business_travel', df.pop('business_travel'))
df.insert(12, 'distance_home', df.pop('distance_home'))
df.insert(13, 'overtime', df.pop('overtime'))
df.insert(14, 'education_area', df.pop('education_area'))
df.insert(15, 'standard_hours', df.pop('standard_hours'))

df
# Out:
#      attrition  employee_id  age age_interval  gender  education  \
# 0          Yes            1   41        40-49  Female          2
# 1           No            2   49        40-49    Male          1
# 2          Yes            4   37        30-39    Male          2
# 3           No            5   33        30-39  Female          4
# 4           No            7   27        18-29    Male          1
# ...        ...          ...  ...          ...     ...        ...
# 1465        No         2061   36        30-39    Male          2
# 1466        No         2062   39        30-39    Male          1
# 1467        No         2064   27        18-29    Male          3
# 1468        No         2065   49        40-49    Male          3
# 1469        No         2068   34        30-39    Male          3
#
#      marital_status              department   job_level  \
# 0            Single                   Sales     analyst
# 1           Married  Research & Development     analyst
# ...

# %%
# Order Salary variables:

df.insert(16, 'daily_rate', df.pop('daily_rate'))
df.insert(17, 'hourly_rate', df.pop('hourly_rate'))
df.insert(18, 'monthly_income', df.pop('monthly_income'))
df.insert(19, 'monthly_rate', df.pop('monthly_rate'))

df
# Out:
#      attrition  employee_id  age age_interval  gender  education  \
# 0          Yes            1   41        40-49  Female          2
# 1           No            2   49        40-49    Male          1
# 2          Yes            4   37        30-39    Male          2
# 3           No            5   33        30-39  Female          4
# 4           No            7   27        18-29    Male          1
# ...        ...          ...  ...          ...     ...        ...
# 1465        No         2061   36        30-39    Male          2
# 1466        No         2062   39        30-39    Male          1
# 1467        No         2064   27        18-29    Male          3
# 1468        No         2065   49        40-49    Male          3
# 1469        No         2068   34        30-39    Male          3
#
#      marital_status              department   job_level  \
# 0            Single                   Sales     analyst
# 1           Married  Research & Development     analyst
# ...

# %%
# Order Employee career variables:

df.insert(20, 'companies_worked', df.pop('companies_worked'))
df.insert(21, 'salary_hike_per', df.pop('salary_hike_per'))
df.insert(22, 'stock_option', df.pop('stock_option'))
df.insert(23, 'working_years', df.pop('working_years'))
df.insert(24, 'training_lastyear', df.pop('training_lastyear'))
df.insert(25, 'years_company', df.pop('years_company'))
df.insert(26, 'years_curr_role', df.pop('years_curr_role'))
df.insert(27, 'years_last_promotion', df.pop('years_last_promotion'))
df.insert(28, 'years_curr_manager', df.pop('years_curr_manager'))

df
# Out:
#      attrition  employee_id  age age_interval  gender  education  \
# 0          Yes            1   41        40-49  Female          2
# 1           No            2   49        40-49    Male          1
# 2          Yes            4   37        30-39    Male          2
# 3           No            5   33        30-39  Female          4
# 4           No            7   27        18-29    Male          1
# ...        ...          ...  ...          ...     ...        ...
# 1465        No         2061   36        30-39    Male          2
# 1466        No         2062   39        30-39    Male          1
# 1467        No         2064   27        18-29    Male          3
# 1468        No         2065   49        40-49    Male          3
# 1469        No         2068   34        30-39    Male          3
#
#      marital_status              department   job_level  \
# 0            Single                   Sales     analyst
# 1           Married  Research & Development     analyst
# ...

# %%
# Order Employee scoring variables:

df.insert(29, 'environment_satisf', df.pop('environment_satisf'))
df.insert(30, 'environment_satisf_cat', df.pop('environment_satisf_cat'))
df.insert(31, 'worklife_balance', df.pop('worklife_balance'))
df.insert(32, 'worklife_balance_cat', df.pop('worklife_balance_cat'))
df.insert(33, 'job_involvement', df.pop('job_involvement'))
df.insert(34, 'job_involvement_cat', df.pop('job_involvement_cat'))
df.insert(35, 'job_satisfaction', df.pop('job_satisfaction'))
df.insert(36, 'job_satisf_cat', df.pop('job_satisf_cat'))
df.insert(37, 'performance_rating', df.pop('performance_rating'))
df.insert(38, 'relationship_satisf', df.pop('relationship_satisf'))

df
# Out:
#      attrition  employee_id  age age_interval  gender  education  \
# 0          Yes            1   41        40-49  Female          2
# 1           No            2   49        40-49    Male          1
# 2          Yes            4   37        30-39    Male          2
# 3           No            5   33        30-39  Female          4
# 4           No            7   27        18-29    Male          1
# ...        ...          ...  ...          ...     ...        ...
# 1465        No         2061   36        30-39    Male          2
# 1466        No         2062   39        30-39    Male          1
# 1467        No         2064   27        18-29    Male          3
# 1468        No         2065   49        40-49    Male          3
# 1469        No         2068   34        30-39    Male          3
#
#      marital_status              department   job_level  \
# 0            Single                   Sales     analyst
# 1           Married  Research & Development     analyst
# ...

# %%
# Order outlier variables:

df.insert(6, 'education_cat', df.pop('education_cat'))
df.insert(7,'education_area', df.pop('education_area'))
df.insert(0, 'employee_id', df.pop('employee_id'))
df.insert(38, 'performance_rating_cat', df.pop('performance_rating_cat'))
df
# Out:
#       employee_id attrition  age age_interval  gender  education  \
# 0               1       Yes   41        40-49  Female          2
# 1               2        No   49        40-49    Male          1
# 2               4       Yes   37        30-39    Male          2
# 3               5        No   33        30-39  Female          4
# 4               7        No   27        18-29    Male          1
# ...           ...       ...  ...          ...     ...        ...
# 1465         2061        No   36        30-39    Male          2
# 1466         2062        No   39        30-39    Male          1
# 1467         2064        No   27        18-29    Male          3
# 1468         2065        No   49        40-49    Male          3
# 1469         2068        No   34        30-39    Male          3
#
#       education_cat education_area marital_status              department  \
# 0           College  Life Sciences         Single                   Sales
# ...

# %%
print(df.distance_home.max())
print(df.distance_home.min())
# Out:
# 29
# 1

# %%
df.distance_home.unique()
# Out:
# array([ 1,  8,  2,  3, 24, 23, 27, 16, 15, 26, 19, 21,  5, 11,  9,  7,  6,
#        10,  4, 25, 12, 18, 29, 22, 14, 20, 28, 17, 13], dtype=int64)

# %%
# Create distance interval variable:

intervalos_nuevos = [1, 5, 10, 15, 20, float('inf')]
etiquetas_nuevas = ['1-5', '6-10', '11-15', '16-20', '20+']
df['distance_interval'] = pd.cut(df['distance_home'], bins=intervalos_nuevos, labels=etiquetas_nuevas, right=False)
df.insert(14, 'distance_interval', df.pop('distance_interval'))
df
# Out:
#       employee_id attrition  age age_interval  gender  education  \
# 0               1       Yes   41        40-49  Female          2
# 1               2        No   49        40-49    Male          1
# 2               4       Yes   37        30-39    Male          2
# 3               5        No   33        30-39  Female          4
# 4               7        No   27        18-29    Male          1
# ...           ...       ...  ...          ...     ...        ...
# 1465         2061        No   36        30-39    Male          2
# 1466         2062        No   39        30-39    Male          1
# 1467         2064        No   27        18-29    Male          3
# 1468         2065        No   49        40-49    Male          3
# 1469         2068        No   34        30-39    Male          3
#
#       education_cat education_area marital_status              department  \
# 0           College  Life Sciences         Single                   Sales
# ...

# %%
df.business_travel.unique()
# Out:
# array(['Travel_Rarely', 'Travel_Frequently', 'Non-Travel'], dtype=object)

# %%
#Modify values from travel variable

mapp_10 = {'Travel_Rarely': 'rarely', 'Travel_Frequently': 'frequently', 'Non-Travel': 'non travel',}
df['business_travel_cat'] = df['business_travel'].map(mapp_10)
df.insert(13,'business_travel_cat', df.pop('business_travel_cat'))

df
# Out:
#       employee_id attrition  age age_interval  gender  education  \
# 0               1       Yes   41        40-49  Female          2
# 1               2        No   49        40-49    Male          1
# 2               4       Yes   37        30-39    Male          2
# 3               5        No   33        30-39  Female          4
# 4               7        No   27        18-29    Male          1
# ...           ...       ...  ...          ...     ...        ...
# 1465         2061        No   36        30-39    Male          2
# 1466         2062        No   39        30-39    Male          1
# 1467         2064        No   27        18-29    Male          3
# 1468         2065        No   49        40-49    Male          3
# 1469         2068        No   34        30-39    Male          3
#
#       education_cat education_area marital_status              department  \
# 0           College  Life Sciences         Single                   Sales
# ...

# %%
mapp_11 = {'Travel_Rarely': 2, 'Travel_Frequently': 3, 'Non-Travel': 1,}
df['business_travel'] = df['business_travel'].map(mapp_11)

df
# Out:
#       employee_id attrition  age age_interval  gender  education  \
# 0               1       Yes   41        40-49  Female          2
# 1               2        No   49        40-49    Male          1
# 2               4       Yes   37        30-39    Male          2
# 3               5        No   33        30-39  Female          4
# 4               7        No   27        18-29    Male          1
# ...           ...       ...  ...          ...     ...        ...
# 1465         2061        No   36        30-39    Male          2
# 1466         2062        No   39        30-39    Male          1
# 1467         2064        No   27        18-29    Male          3
# 1468         2065        No   49        40-49    Male          3
# 1469         2068        No   34        30-39    Male          3
#
#       education_cat education_area marital_status              department  \
# 0           College  Life Sciences         Single                   Sales
# ...

# %%
df['annual_income'] = df['monthly_income'] * 14
df.insert(22,'annual_income', df.pop('annual_income'))

df
# Out:
#       employee_id attrition  age age_interval  gender  education  \
# 0               1       Yes   41        40-49  Female          2
# 1               2        No   49        40-49    Male          1
# 2               4       Yes   37        30-39    Male          2
# 3               5        No   33        30-39  Female          4
# 4               7        No   27        18-29    Male          1
# ...           ...       ...  ...          ...     ...        ...
# 1465         2061        No   36        30-39    Male          2
# 1466         2062        No   39        30-39    Male          1
# 1467         2064        No   27        18-29    Male          3
# 1468         2065        No   49        40-49    Male          3
# 1469         2068        No   34        30-39    Male          3
#
#       education_cat education_area marital_status              department  \
# 0           College  Life Sciences         Single                   Sales
# ...
